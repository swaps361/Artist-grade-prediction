# %% [markdown]
# #### Artist_grade prediction project where I have used my own data in csv file which consists of a brief about professional art classes

# %%
#Importing libraries
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %% [markdown]
# #### 1)school- refers to the school name from where the students are learning Art
# #### 2)sex-refers to the gender of student
# #### 3)age-refers to the age of student
# #### 4)address-'U':refers to urban areas and 'R':refers to rural areas
# #### 5)Astatus-refers to the assignment status of student.if yes then he/she has completed the assignment.
# #### 6)status-'B':refers to beginner and 'I':refers to intermediate
# #### 7)guardian-refers to the guardian of the student
# #### 8)failures-refer to the number of failures
# #### 9)P(out of 5)-refers to the performance marks out of 5
# #### 10)absences-number of absences
# #### 11)mode-refers to the mode of painting
# #### 12)Final-final grade
# #### 13)paid-if the fees is paid or not
# #### 14)activities-if the student is regular in activities

# %%
#Loading the dataset
data=pd.read_csv("artist.csv")
data
# Out:
#     school sex  age address Astatus status guardian  failures  P(out of 5)  \
# 0   Loyola   F   19       U     yes      B   mother         0            2
# 1   Loyola   F   18       U     yes      I   father         0            4
# 2   Loyola   F   17       U     yes      I   mother         3            2
# 3   Loyola   F   15       U     yes      I   mother         0            4
# 4   Loyola   F   15       U     yes      I   father         0            4
# 5   Loyola   M   16       U     yes      I   mother         0            4
# 6   Loyola   M   16       U     yes      B   mother         0            2
# 7   Loyola   F   16       U     yes      B   mother         0            2
# 8   Loyola   M   17       U     yes      B   mother         0            2
# 9   Loyola   M   15       U     yes      B   mother         0            2
# 10  Loyola   F   15       U     yes      B   mother         0            2
# 11  Loyola   F   15       U     yes      B   father         0            2
# 12  Loyola   M   15       U     yes      B   father         0            2
# 13  Loyola   M   15       U     yes      B   mother         0            2
# 14  Loyola   M   15       U     yes      B    other         0            2
# 15  Loyola   F   15       U     yes      B   mother         0            2
# 16  Loyola   F   16       U      no      B   mother         0            2
# 17  Loyola   F   16       U      no      B   mother         0            2
# 18  Loyola   M   16       U      no      B   mother         3            2
# 19  Loyola   M   17       U      no      B   father         0            2
# 20    DBMS   M   16       U      no      B   mother         0            2
# 21    DBMS   M   15       U     yes      B   father         0            2
# 22    DBMS   M   15       U     yes      B   mother         0            2
# 23    DBMS   M   16       U     yes      B   mother         0            2
# 24    DBMS   F   16       R     yes      B   mother         0            2
# 25    DBMS   F   15       U      no      B   mother         3            2
# 26    DBMS   M   16       U      no      B   mother         0            2
# 27    DBMS   M   15       U     yes      B   mother         0            2
# 28    DBMS   M   15       U     yes      B   mother         0            2
# 29    DBMS   M   16       U     yes      B   mother         0            2
# 30    DBMS   M   16       U     yes      B   mother         0            2
# 31    DBMS   M   15       U     yes      B   mother         0            2
# 32    DBMS   M   15       R     yes      B   mother         0            2
# 33    DBMS   M   15       U     yes      B   mother         0            2
# 34    DBMS   M   15       U     yes      B   mother         0            2
# 35    DBMS   F   16       U     yes      B   father         0            2
# 36    DBMS   M   15       U      no      B   mother         0            4
# 37    DBMS   M   15       R     yes      B   mother         0            4
# 38    DBMS   F   16       R      no      B   mother         0            4
# 39    DBMS   F   15       R     yes      B   mother         0            4
# 40    DBMS   F   15       U     yes      B   mother         1            4
# 41    DBMS   M   16       U     yes      B    other         0            4
# 42    DBMS   M   15       U     yes      B   father         0            4
# 43    DBMS   M   15       U     yes      B   father         0            4
# 44    DBMS   F   15       U     yes      B   father         1            4
# 45    DBMS   F   16       U     yes      B   mother         0            4
# 46    DBMS   F   15       U     yes      B   mother         0            4
# 47    DBMS   M   16       U     yes      B   mother         0            4
# 48    DBMS   M   16       U     yes      B   mother         0            4
#
#     absences        mode  Final paid activities
# 0          6     acrylic      5   no         no
# 1          4  watercolor     10   no         no
# 2         10  watercolor      2  yes         no
# 3          2  watercolor     10  yes        yes
# 4          4  watercolor     10  yes         no
# 5         10  watercolor     10  yes        yes
# 6          0  watercolor      5   no         no
# 7          6  watercolor      5   no         no
# 8          0  watercolor      5  yes         no
# 9          0  watercolor      5  yes        yes
# 10         0  watercolor      5  yes         no
# 11         4  watercolor      5   no        yes
# 12         2  watercolor      5  yes        yes
# 13         2  watercolor      5  yes         no
# 14         0  watercolor      5   no         no
# 15         4  watercolor      5   no         no
# 16         6  watercolor      5  yes        yes
# 17         4  watercolor      5   no        yes
# 18        16  watercolor      2   no        yes
# 19         4  watercolor      5  yes        yes
# 20         0  watercolor      5   no         no
# 21         0     acrylic      5  yes         no
# 22         2     acrylic      5   no        yes
# 23         0     acrylic      5   no        yes
# 24         2     acrylic      5  yes        yes
# 25        14     acrylic      2  yes         no
# 26         2     acrylic      5  yes         no
# 27         4     acrylic      5  yes         no
# 28         4     acrylic      5   no        yes
# 29        16     acrylic      5  yes        yes
# 30         0     acrylic      5  yes         no
# 31         0     acrylic      5   no        yes
# 32         0     acrylic      5   no        yes
# 33         0     acrylic      5   no        yes
# 34         0     acrylic      5  yes         no
# 35         0     acrylic      5   no        yes
# 36         2     acrylic     10   no        yes
# 37         7     acrylic     10   no        yes
# 38         2     acrylic     10  yes        yes
# 39         8     acrylic     10  yes        yes
# 40        25     acrylic     10   no        yes
# 41         8  watercolor     10   no         no
# 42         2  watercolor     10   no        yes
# 43         0  watercolor     10   no         no
# 44        14  watercolor     10   no        yes
# 45         8  watercolor     10  yes        yes
# 46        12  watercolor     10   no         no
# 47         4  watercolor     10   no        yes
# 48         2  watercolor     10  yes         no

# %%
data.head()
# Out:
#    school sex  age address Astatus status guardian  failures  P(out of 5)  \
# 0  Loyola   F   19       U     yes      B   mother         0            2
# 1  Loyola   F   18       U     yes      I   father         0            4
# 2  Loyola   F   17       U     yes      I   mother         3            2
# 3  Loyola   F   15       U     yes      I   mother         0            4
# 4  Loyola   F   15       U     yes      I   father         0            4
#
#    absences        mode  Final paid activities
# 0         6     acrylic      5   no         no
# 1         4  watercolor     10   no         no
# 2        10  watercolor      2  yes         no
# 3         2  watercolor     10  yes        yes
# 4         4  watercolor     10  yes         no

# %% [markdown]
# ## Data Preprocessing

# %%
#number of rows and columns
data.shape
# Out:
# (49, 14)

# %% [markdown]
# #### Final Grade

# %%
data['Final'].describe()
# Out:
# count    49.000000
# mean      6.551020
# std       2.638349
# min       2.000000
# 25%       5.000000
# 50%       5.000000
# 75%      10.000000
# max      10.000000
# Name: Final, dtype: float64

# %%
plt.plot(data['Final'], color='r')
plt.title('Final Grade', fontsize=20)
plt.xlabel('Final Grade', fontsize=15)
plt.ylabel('Count', fontsize=15)
plt.show()

# %%
#since we do not need the null values for prediction ,we find them and convert them to 0
data.isnull().any()
# Out:
# school         False
# sex            False
# age            False
# address        False
# Astatus        False
# status         False
# guardian       False
# failures       False
# P(out of 5)    False
# absences       False
# mode           False
# Final          False
# paid           False
# activities     False
# dtype: bool

# %%
data.isnull().sum()
# Out:
# school         0
# sex            0
# age            0
# address        0
# Astatus        0
# status         0
# guardian       0
# failures       0
# P(out of 5)    0
# absences       0
# mode           0
# Final          0
# paid           0
# activities     0
# dtype: int64

# %%
#Counting the number of males and females
male_student = len(data[data['sex'] == 'M'])
female_student= len(data[data['sex'] == 'F'])
print('Number of male students:',male_student)
print('Number of female students:',female_student)
# Out:
# Number of male students: 29
# Number of female students: 20

# %% [markdown]
# ## Data Visualization

# %%
#Determines the age with respect to sex
plt.boxplot(data['age'], vert=False, patch_artist=True, boxprops=dict(facecolor='g'))
plt.title('Age Distribution', fontsize=20)
plt.xlabel('Age', fontsize=15)
plt.ylabel('Sex', fontsize=15)
plt.show()

# %%
#range of age
plt.boxplot(data['age'], patch_artist=True, boxprops=dict(facecolor='g'))
plt.title('Age Distribution', fontsize=20)
plt.xlabel('Age', fontsize=15)
plt.ylabel('Count', fontsize=15)
plt.show()

# %%
plt.plot(data['address'], color='r')
plt.title('Urban vs Rural Students', fontsize=20)
plt.xlabel('Address', fontsize=15)
plt.ylabel('Count', fontsize=15)
plt.show()

# %%
#dropping the unnecessary columns
data.drop(["school","age"], axis=1, inplace=True)

# %%
data.head()
# Out:
#   sex address Astatus status guardian  failures  P(out of 5)  absences  \
# 0   F       U     yes      B   mother         0            2         6
# 1   F       U     yes      I   father         0            4         4
# 2   F       U     yes      I   mother         3            2        10
# 3   F       U     yes      I   mother         0            4         2
# 4   F       U     yes      I   father         0            4         4
#
#          mode  Final paid activities
# 0     acrylic      5   no         no
# 1  watercolor     10   no         no
# 2  watercolor      2  yes         no
# 3  watercolor     10  yes        yes
# 4  watercolor     10  yes         no

# %%
data_dum=data

# %%
#Converting to categorical value
categorical_d = {'yes': 1, 'no': 0}
data_dum['Astatus'] = data_dum['Astatus'].map(categorical_d)
data_dum['paid'] = data_dum['paid'].map(categorical_d)
data_dum['activities'] = data_dum['activities'].map(categorical_d)

# %%
categorical_d = {'F': 1, 'M': 0}
data_dum['sex'] = data_dum['sex'].map(categorical_d)

# map the address data
categorical_d = {'U': 1, 'R': 0}
data_dum['address'] = data_dum['address'].map(categorical_d)

categorical_d = {'I': 1, 'B': 0}
data_dum['status'] = data_dum['status'].map(categorical_d)

categorical_d = {'acrylic': 1, 'watercolor': 0}
data_dum['mode'] = data_dum['mode'].map(categorical_d)

# map the guardian data
categorical_d = {'mother': 0, 'father': 1, 'other': 2}
data_dum['guardian'] = data_dum['guardian'].map(categorical_d)

# %%
data_dum
# Out:
#     sex  address  Astatus  status  guardian  failures  P(out of 5)  absences  \
# 0     1        1        1       0         0         0            2         6
# 1     1        1        1       1         1         0            4         4
# 2     1        1        1       1         0         3            2        10
# 3     1        1        1       1         0         0            4         2
# 4     1        1        1       1         1         0            4         4
# 5     0        1        1       1         0         0            4        10
# 6     0        1        1       0         0         0            2         0
# 7     1        1        1       0         0         0            2         6
# 8     0        1        1       0         0         0            2         0
# 9     0        1        1       0         0         0            2         0
# 10    1        1        1       0         0         0            2         0
# 11    1        1        1       0         1         0            2         4
# 12    0        1        1       0         1         0            2         2
# 13    0        1        1       0         0         0            2         2
# 14    0        1        1       0         2         0            2         0
# 15    1        1        1       0         0         0            2         4
# 16    1        1        0       0         0         0            2         6
# 17    1        1        0       0         0         0            2         4
# 18    0        1        0       0         0         3            2        16
# 19    0        1        0       0         1         0            2         4
# 20    0        1        0       0         0         0            2         0
# 21    0        1        1       0         1         0            2         0
# 22    0        1        1       0         0         0            2         2
# 23    0        1        1       0         0         0            2         0
# 24    1        0        1       0         0         0            2         2
# 25    1        1        0       0         0         3            2        14
# 26    0        1        0       0         0         0            2         2
# 27    0        1        1       0         0         0            2         4
# 28    0        1        1       0         0         0            2         4
# 29    0        1        1       0         0         0            2        16
# 30    0        1        1       0         0         0            2         0
# 31    0        1        1       0         0         0            2         0
# 32    0        0        1       0         0         0            2         0
# 33    0        1        1       0         0         0            2         0
# 34    0        1        1       0         0         0            2         0
# 35    1        1        1       0         1         0            2         0
# 36    0        1        0       0         0         0            4         2
# 37    0        0        1       0         0         0            4         7
# 38    1        0        0       0         0         0            4         2
# 39    1        0        1       0         0         0            4         8
# 40    1        1        1       0         0         1            4        25
# 41    0        1        1       0         2         0            4         8
# 42    0        1        1       0         1         0            4         2
# 43    0        1        1       0         1         0            4         0
# 44    1        1        1       0         1         1            4        14
# 45    1        1        1       0         0         0            4         8
# 46    1        1        1       0         0         0            4        12
# 47    0        1        1       0         0         0            4         4
# 48    0        1        1       0         0         0            4         2
#
#     mode  Final  paid  activities
# 0      1      5     0           0
# 1      0     10     0           0
# 2      0      2     1           0
# 3      0     10     1           1
# 4      0     10     1           0
# 5      0     10     1           1
# 6      0      5     0           0
# 7      0      5     0           0
# 8      0      5     1           0
# 9      0      5     1           1
# 10     0      5     1           0
# 11     0      5     0           1
# 12     0      5     1           1
# 13     0      5     1           0
# 14     0      5     0           0
# 15     0      5     0           0
# 16     0      5     1           1
# 17     0      5     0           1
# 18     0      2     0           1
# 19     0      5     1           1
# 20     0      5     0           0
# 21     1      5     1           0
# 22     1      5     0           1
# 23     1      5     0           1
# 24     1      5     1           1
# 25     1      2     1           0
# 26     1      5     1           0
# 27     1      5     1           0
# 28     1      5     0           1
# 29     1      5     1           1
# 30     1      5     1           0
# 31     1      5     0           1
# 32     1      5     0           1
# 33     1      5     0           1
# 34     1      5     1           0
# 35     1      5     0           1
# 36     1     10     0           1
# 37     1     10     0           1
# 38     1     10     1           1
# 39     1     10     1           1
# 40     1     10     0           1
# 41     0     10     0           0
# 42     0     10     0           1
# 43     0     10     0           0
# 44     0     10     0           1
# 45     0     10     1           1
# 46     0     10     0           0
# 47     0     10     0           1
# 48     0     10     1           0

# %%
data_dum.columns
# Out:
# Index(['sex', 'address', 'Astatus', 'status', 'guardian', 'failures',
#        'P(out of 5)', 'absences', 'mode', 'Final', 'paid', 'activities'],
#       dtype='object')

# %%
from sklearn.model_selection import train_test_split
x=data_dum.drop("Final",axis=1)
y=data_dum['Final']

# %%
data_dum['Final']
# Out:
# 0      5
# 1     10
# 2      2
# 3     10
# 4     10
# 5     10
# 6      5
# 7      5
# 8      5
# 9      5
# 10     5
# 11     5
# 12     5
# 13     5
# 14     5
# 15     5
# 16     5
# 17     5
# 18     2
# 19     5
# 20     5
# 21     5
# 22     5
# 23     5
# 24     5
# 25     2
# 26     5
# 27     5
# 28     5
# 29     5
# 30     5
# 31     5
# 32     5
# 33     5
# 34     5
# 35     5
# 36    10
# 37    10
# 38    10
# 39    10
# 40    10
# 41    10
# 42    10
# 43    10
# 44    10
# 45    10
# 46    10
# 47    10
# 48    10
# Name: Final, dtype: int64

# %% [markdown]
# ## Model Training

# %%
X_train, X_test, y_train, y_test = train_test_split(x,y, test_size = 0.20, random_state=44)

# %%
from sklearn.linear_model import LinearRegression

# %%
L=LinearRegression()

# %%
L.fit(X_train, y_train)
# Out:
# LinearRegression()

# %% [markdown]
# ## Model Evaluation

# %%
y_pred=L.predict(X_test)

# %%
#shows the accuracy of model

print(L.score(X_test, y_test))
# Out:
# 0.966666666666656

# %%
plt.plot(data['P(out of 5)'], data['Final'], color='g')
plt.xlabel('Performance', fontsize=15)
plt.ylabel('Final Score', fontsize=15)
plt.show()
